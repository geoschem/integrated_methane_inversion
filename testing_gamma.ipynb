# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# 80/20 per file
gamma_data_old = [
    {"Ja": 1.1682162626799e-06,"label": 1e-06, "rmse_test": 2.091727865639612, "rmse_train": 2.0627272132996666},
    {"Ja": 1.1843821019185665e-05,"label": 1e-05, "rmse_test": 1.304512090727018, "rmse_train": 1.2715035989051968},
    {"Ja": 3.9833753893514425e-05,"label": 0.0001, "rmse_test": 0.9849475948358027, "rmse_train": 0.95111791075289},
    {"Ja": 0.0012640678075347383,"label": 0.001, "rmse_test": 0.949441041828899, "rmse_train": 0.9156611540237397},
    {"Ja": 0.043115112412484356,"label": 0.01, "rmse_test": 0.9621005030975752, "rmse_train": 0.9326878899295832},
    {"Ja": 0.600768149551393,"label": 0.1, "rmse_test": 0.9771415276314168, "rmse_train": 0.9608067168337914},
    {"Ja": 1.2310113727122076,"label": 0.25, "rmse_test": 0.9822308166986173, "rmse_train": 0.9700652243493907},
    {"Ja": 2.0103770432209775,"label": 0.5, "rmse_test": 0.9856663614394598, "rmse_train": 0.9754816225092062},
    {"Ja": 2.659204703675782,"label": 0.75, "rmse_test": 0.9875856250404161, "rmse_train": 0.9781219693170786},
    {"Ja": 3.2368854593983634,"label": 1.0, "rmse_test": 0.9889049771271183, "rmse_train": 0.9797913890913509},
]
# 1/5 files for test
gamma_data = [
{"Ja": 1.300085638537457e-06, "label": 1e-06, "rmse_test": 1.691643995850622, "rmse_train": 2.1340363942871483},
{"Ja": 1.3170548233132514e-05, "label": 1e-05, "rmse_test": 0.8380868375560437, "rmse_train": 1.2989446306975054},
{"Ja": 3.937953539090573e-05, "label": 0.0001, "rmse_test": 0.49023819605404384, "rmse_train": 0.9593754681968331},
{"Ja": 0.0011515868437004119, "label": 0.001, "rmse_test": 0.44607331218326657, "rmse_train": 0.9194189830279577},
{"Ja": 0.0419761647020836, "label": 0.01, "rmse_test": 0.4789221038131152, "rmse_train": 0.934051801094965},
{"Ja": 0.593663375946078, "label": 0.1, "rmse_test": 0.5623224593490551, "rmse_train": 0.9609408957734787},
{"Ja": 1.2213988172812522, "label": 0.25, "rmse_test": 0.58315025037939, "rmse_train": 0.9699267880786614},
{"Ja": 2.006782370331124, "label": 0.5, "rmse_test": 0.591343514545882, "rmse_train": 0.9752102475248402},
{"Ja": 2.6661915283036413, "label": 0.75, "rmse_test": 0.5943399825227791, "rmse_train": 0.9777924522659517},
{"Ja": 3.2557833912955583, "label": 1.0, "rmse_test": 0.5960372613006266, "rmse_train": 0.979427532900998},
]
# 1/5 files for test
gamma_data1 = [
{"Ja": 1.300085638537457e-06,"label": 1e-06, "rmse_test": -1.691643995850622, "rmse_train": -2.1340363942871483},
{"Ja": 1.3170548233132514e-05,"label": 1e-05, "rmse_test": -0.8380868375560437, "rmse_train": -1.2989446306975054},
{"Ja": 3.937953539090573e-05,"label": 0.0001, "rmse_test": -0.49023819605404384, "rmse_train": -0.9593754681968331},
{"Ja": 0.0011515868437004119,"label": 0.001, "rmse_test": -0.44607331218326657, "rmse_train": -0.9194189830279577},
{"Ja": 0.0419761647020836,"label": 0.01, "rmse_test": -0.4789221038131152, "rmse_train": -0.934051801094965},
{"Ja": 0.593663375946078,"label": 0.1, "rmse_test": -0.5623224593490551, "rmse_train": -0.9609408957734787},
{"Ja": 1.2213988172812522,"label": 0.25, "rmse_test": -0.58315025037939, "rmse_train": -0.9699267880786614},
{"Ja": 2.006782370331124,"label": 0.5, "rmse_test": -0.591343514545882, "rmse_train": -0.9752102475248402},
{"Ja": 2.6661915283036413,"label": 0.75, "rmse_test": -0.5943399825227791, "rmse_train": -0.9777924522659517},
{"Ja": 3.2557833912955583,"label": 1.0, "rmse_test": -0.5960372613006266, "rmse_train": -0.979427532900998},
{"Ja": 15.180830467891862,"label": 10.0, "rmse_test": -0.607039751149138, "rmse_train": -0.9878825281764906},
{"Ja": 63.71976647822897,"label": 100.0, "rmse_test": -0.6141666200235041, "rmse_train": -0.991490988978353},
]

# new way permian
gamma_data_permian = [
    {"Ja": 3.06191668519511e-11, "label": 1e-06, "rmse_train": -2.39810833871479, "rmse_test": -1.219689533787063},
    {"Ja": 3.061381557458012e-09, "label": 1e-05, "rmse_train": -2.3978702868884403, "rmse_test": -1.2194562336929318},
    {"Ja": 3.056040145068264e-07, "label": 0.0001, "rmse_train": -2.395492873499955, "rmse_test": -1.2171261380814715},
    {"Ja": 3.0035943557866232e-05, "label": 0.001, "rmse_train": -2.3720248256891225, "rmse_test": -1.1941117365867246},
    {"Ja": 0.002560664091270161, "label": 0.01, "rmse_train": -2.1641235064519817, "rmse_test": -0.9891468772869836},
    {"Ja": 0.09719706194335352, "label": 0.1, "rmse_train": -1.2111046858617474, "rmse_test": -0.020428552214304795},
    {"Ja": 0.26060480702122296, "label": 0.25, "rmse_train": -0.7223660565386787, "rmse_test": 0.5048897751665292},
    {"Ja": 0.459063429068385, "label": 0.5, "rmse_train": -0.4329946906014982, "rmse_test": 0.8339229789337874},
    {"Ja": 0.6103422497793684, "label": 0.75, "rmse_train": -0.3073333529536093, "rmse_test": 0.9841613265800706},
    {"Ja": 0.7413780035919484, "label": 1.0, "rmse_train": -0.2372532170470171, "rmse_test": 1.0712953613179639},
    {"Ja": 4.24986882798123, "label": 10.0, "rmse_train": -0.04275645671466486, "rmse_test": 1.3883070269353361},
    # {"Ja": 22.355955034785467, "label": 100.0, "rmse_train": -0.03375215511857617, "rmse_test": 1.4958162907946497},
]

# kfold us
gamma_data_us = [
    {"Ja": 1.2859017270605462e-06, "label": 1e-06, "rmse_train": -2.064511719498939, "rmse_test": -2.0170780069645793},
    {"Ja": 1.3385523448857743e-05, "label": 1e-05, "rmse_train": -1.2749734234638725, "rmse_test": -1.217705633875521},
    {"Ja": 4.382802842098522e-05, "label": 0.0001, "rmse_train": -0.9556514744427961, "rmse_test": -0.8822520363420262},
    {"Ja": 0.0012871978718216838, "label": 0.001, "rmse_train": -0.9200398082578511, "rmse_test": -0.8411402750453378},
    {"Ja": 0.043493181220693164, "label": 0.01, "rmse_train": -0.9369395637226734, "rmse_test": -0.861074638236668},
    {"Ja": 0.6109013119202976, "label": 0.1, "rmse_train": -0.9646483922839136, "rmse_test": -0.8935472648445592},
    {"Ja": 1.2651462676120568, "label": 0.25, "rmse_train": -0.973843254237963, "rmse_test": -0.914616936969592},
    {"Ja": 2.0862923605741175, "label": 0.5, "rmse_train": -0.9792780893041965, "rmse_test": -0.9302381558336255},
    {"Ja": 2.775427297492178, "label": 0.75, "rmse_train": -0.981945464025797, "rmse_test": -0.9388498534797447},
    {"Ja": 3.3914532195506895, "label": 1.0, "rmse_train": -0.9836390449786327, "rmse_test": -0.9446513357581872},
    {"Ja": 15.8692741194728, "label": 10.0, "rmse_train": -0.9925052846876639, "rmse_test": -0.9792162279659969},
    {"Ja": 65.47156121257919, "label": 100.0, "rmse_train": -0.9963380870494186, "rmse_test": -0.9976594141387656},
]

# megan global
gamma_data_global = [
    {"Ja": 9.971537019009138e-06, "label": 1e-06, "rmse_train": -6.404416224431287, "rmse_test": -6.362406204292268},
    {"Ja": 0.00035115529555538455, "label": 1e-05, "rmse_train": -4.038884580853251, "rmse_test": -4.217730808116029},
    {"Ja": 0.0015443801928801538, "label": 0.0001, "rmse_train": -1.1309787196179013, "rmse_test": -1.2192067670053819},
    {"Ja": 0.0050046925799104745, "label": 0.001, "rmse_train": -0.3400416765730481, "rmse_test": -0.29030979302644316},
    {"Ja": 0.04781901687661351, "label": 0.01, "rmse_train": -0.1529093613984736, "rmse_test": -0.02909862021826326},
    {"Ja": 0.4926395409407672, "label": 0.1, "rmse_train": -0.09883402709889191, "rmse_test": 0.0017017021715884928},
    {"Ja": 1.218928564736237, "label": 0.25, "rmse_train": -0.08747795426081403, "rmse_test": 0.011286786879724443},
    {"Ja": 2.3773676713201835, "label": 0.5, "rmse_train": -0.08044941313940882, "rmse_test": 0.015173925879026528},
    {"Ja": 3.490591686337246, "label": 0.75, "rmse_train": -0.07677353625414352, "rmse_test": 0.014669074439038688},
    {"Ja": 4.569447231568018, "label": 1.0, "rmse_train": -0.07431263603274721, "rmse_test": 0.013226851092348202},
    {"Ja": 35.44608153731572, "label": 10.0, "rmse_train": -0.05889930058276891, "rmse_test": 0.015514480982366874},
    {"Ja": 310.33391326142737, "label": 100.0, "rmse_train": -0.07199215582691039, "rmse_test": 0.005598080565231545},
]
gamma_data_conus_1mon = [
    {"Ja": 3.343926689064994e-08, "label": 1e-06, "rmse_train": -1.6346426925618704, "rmse_test": -1.6468461412629103},
    {"Ja": 2.883572550403156e-06, "label": 1e-05, "rmse_train": -1.5981144287604026, "rmse_test": -1.590363540644558},
    {"Ja": 0.00013820803963352494, "label": 0.0001, "rmse_train": -1.4810172145202452, "rmse_test": -1.4101648574454273},
    {"Ja": 0.0018477075109203434, "label": 0.001, "rmse_train": -1.2874337010580779, "rmse_test": -1.2167271938420507},
    {"Ja": 0.011489954749378552, "label": 0.01, "rmse_train": -1.1510804509230994, "rmse_test": -1.0846274329778804},
    {"Ja": 0.34988700541048534, "label": 0.1, "rmse_train": -1.1331848076041742, "rmse_test": -1.0852475051388795},
    {"Ja": 1.1038840192236932, "label": 0.25, "rmse_train": -1.134337316299204, "rmse_test": -1.090624078211492},
    {"Ja": 2.286486146671371, "label": 0.5, "rmse_train": -1.135684825691901, "rmse_test": -1.0954110616847292},
    {"Ja": 3.3591069009331482, "label": 0.75, "rmse_train": -1.1362724249380625, "rmse_test": -1.0988652455259624},
    {"Ja": 4.358679886292853, "label": 1.0, "rmse_train": -1.1365007044639717, "rmse_test": -1.1015320936787896},
    {"Ja": 29.682067462746026, "label": 10.0, "rmse_train": -1.13310568316959, "rmse_test": -1.1242968892294514},
    {"Ja": 166.30731473098632, "label": 100.0, "rmse_train": -1.1316368215799877, "rmse_test": -1.1456003556156318},
]

gamma_data = [
    {"Ja": 1.4307011298410795e-08, "label": 1e-06, "rmse_train": -1.6467630223867775, "rmse_test": -1.6412599849980745},
    {"Ja": 1.3227852712711658e-06, "label": 1e-05, "rmse_train": -1.6401455596968781, "rmse_test": -1.588220272624147},
    {"Ja": 7.704463015257437e-05, "label": 0.0001, "rmse_train": -1.5798908497510662, "rmse_test": -1.240336331675634},
    {"Ja": 0.0013574731557406605, "label": 0.001, "rmse_train": -1.3672379851981622, "rmse_test": -0.5742145876748302},
    {"Ja": 0.00786205848857122, "label": 0.01, "rmse_train": -1.1690043231840148, "rmse_test": -0.22560169902883492},
    {"Ja": 0.20740394167096604, "label": 0.1, "rmse_train": -1.1337245370620348, "rmse_test": -0.25569454218620963},
    {"Ja": 0.7321697964960343, "label": 0.25, "rmse_train": -1.1353830854776603, "rmse_test": -0.2869740404726664},
    {"Ja": 1.6863956661747053, "label": 0.5, "rmse_train": -1.1385975518771925, "rmse_test": -0.3202790335105439},
    {"Ja": 2.629880372217915, "label": 0.75, "rmse_train": -1.1406535133599183, "rmse_test": -0.3542064167509239},
    {"Ja": 3.5459726559072218, "label": 1.0, "rmse_train": -1.1420441304987676, "rmse_test": -0.3879602447159608},
    {"Ja": 30.588648502451377, "label": 10.0, "rmse_train": -1.1488140922428292, "rmse_test": -0.8973069609661922},
    {"Ja": 206.06579125386708, "label": 100.0, "rmse_train": -1.1526888772622137, "rmse_test": -1.3499780018779286},
]

# 1yr
gamma_data = [
    {"Ja": 1.1379471871760322e-06, "label": 1e-06, "rmse_train": -2.0995894891072973, "rmse_test": -2.040808396551111},
    {"Ja": 1.4557362430820444e-05, "label": 1e-05, "rmse_train": -1.3299418536419185, "rmse_test": -1.228277425081787},
    {"Ja": 4.487509024958959e-05, "label": 0.0001, "rmse_train": -0.973355034953714, "rmse_test": -0.8016897007865472},
    {"Ja": 0.0009890780389398281, "label": 0.001, "rmse_train": -0.926952552589985, "rmse_test": -0.6898109501118851},
    {"Ja": 0.03410733750639833, "label": 0.01, "rmse_train": -0.9416881964453981, "rmse_test": -0.6296272760222763},
    {"Ja": 0.5318085950997146, "label": 0.1, "rmse_train": -0.9686258199704136, "rmse_test": -0.6247791927492583},
    {"Ja": 1.1473672845956564, "label": 0.25, "rmse_train": -0.9780831609541565, "rmse_test": -0.6364190583477992},
    {"Ja": 1.9289731564723394, "label": 0.5, "rmse_train": -0.9837638478239142, "rmse_test": -0.6468489621333872},
    {"Ja": 2.5899117679348422, "label": 0.75, "rmse_train": -0.9865610159458549, "rmse_test": -0.6533759749383408},
    {"Ja": 3.185574701648836, "label": 1.0, "rmse_train": -0.9883379834202258, "rmse_test": -0.6581455378450072},
    {"Ja": 15.733495673558588, "label": 10.0, "rmse_train": -0.997722007331093, "rmse_test": -0.6915030331780061},
    {"Ja": 67.87276945588552, "label": 100.0, "rmse_train": -1.0019291718516519, "rmse_test": -0.7076363137667186},
]
gamma_data = [
    {"Ja": 9.390919309870818e-07, "label": 1e-06, "rmse_train": -2.114872735331261, "rmse_test": -2.0968945782917543},
    {"Ja": 1.738460477529443e-05, "label": 1e-05, "rmse_train": -1.4065234593417029, "rmse_test": -1.2735376887246572},
    {"Ja": 5.945971534323841e-05, "label": 0.0001, "rmse_train": -0.9960662218609847, "rmse_test": -0.6882523702575004},
    {"Ja": 0.0007461118682722358, "label": 0.001, "rmse_train": -0.9363299799368683, "rmse_test": -0.5713990048819158},
    {"Ja": 0.023625146022182752, "label": 0.01, "rmse_train": -0.9529231952696295, "rmse_test": -0.6145146645794863},
    {"Ja": 0.4156301332812554, "label": 0.1, "rmse_train": -0.9815726577471502, "rmse_test": -0.6273832019177845},
    {"Ja": 0.9425589494342478, "label": 0.25, "rmse_train": -0.9924058790048821, "rmse_test": -0.6038243045268565},
    {"Ja": 1.6169115820293811, "label": 0.5, "rmse_train": -0.9990921085610924, "rmse_test": -0.5842614245683533},
    {"Ja": 2.1837892312425664, "label": 0.75, "rmse_train": -1.0023918820925781, "rmse_test": -0.5743699928390229},
    {"Ja": 2.693627617830786, "label": 1.0, "rmse_train": -1.0044840571123652, "rmse_test": -0.5684530119168851},
    {"Ja": 13.673118356613177, "label": 10.0, "rmse_train": -1.0153074228137464, "rmse_test": -0.5592757151352978},
    {"Ja": 61.48054015049762, "label": 100.0, "rmse_train": -1.0196960708411953, "rmse_test": -0.614525472875713},
]


rmse_test = np.abs([x["rmse_test"] for x in gamma_data])
rmse_train = np.abs([x["rmse_train"] for x in gamma_data])
labels = [x["label"] for x in gamma_data]
ja = [x["Ja"] for x in gamma_data]

# make fig with 2 axs
fig, axs = plt.subplots(2, 2, figsize=(20, 15))
axs = axs.ravel()
axs[0].plot(labels, np.array(rmse_test)*0, color="green", linestyle="--", label="Zero Line")
axs[0].plot(labels, rmse_test, marker="o", label="Mean Absolute Bias Test")

axs[0].set_xlabel("Gamma")
axs[0].set_ylabel("Mean Absolute Bias Test (ppb)")
axs[0].set_title("Gamma vs Mean Absolute Bias Test")
# add second y axis
ax0_twin = axs[0].twinx()
ax0_twin.plot(labels, ja, marker="o", label="Normalized Ja value", color="red")
axs[0].legend()
axs[0].set_xscale("log")

subset = 10
axs[1].plot(labels[:subset], np.array(rmse_test[:subset])*0, color="green", linestyle="--", label="Zero Line")
axs[1].plot(labels[:subset], rmse_test[:subset], marker="o", label="Mean Absolute Bias Test")
axs[1].set_xlabel("Gamma")
axs[1].set_ylabel("Mean Absolute Bias Test (ppb)")
axs[1].set_title("Gamma vs Mean Absolute Bias Test Zoomed into elbow")
axs[1].set_xscale("log")
for i, txt in enumerate(labels[:subset]):
    axs[1].annotate(txt, (labels[i], rmse_test[i]))

axs[2].plot(labels, np.abs(np.array(rmse_test) - np.array(rmse_train)), marker="o", label="Mean Absolute Bias Train")
axs[2].set_xlabel("Gamma")
axs[2].set_ylabel("Difference")
axs[2].set_title("Absolute difference between Mean Absolute Bias Test and Mean Absolute Bias Train")
axs[2].set_xscale("log")

axs[3].plot(labels[:subset], np.abs(np.array(rmse_test[:subset]) - np.array(rmse_train[:subset])), marker="o", label="Mean Absolute Bias Train")
axs[3].set_xlabel("Gamma")
axs[3].set_ylabel("Mean Absolute Bias Train")
axs[3].set_title("Gamma vs Mean Absolute Bias Train Zoomed into elbow")
axs[3].set_xscale("log")

# %%
rmse_test_permian = np.abs([x["rmse_test"] for x in gamma_data_permian])
rmse_test_us = np.abs([x["rmse_test"] for x in gamma_data_us])
rmse_test_global = np.abs([x["rmse_test"] for x in gamma_data_global])
rmse_test_conus1mon = np.abs([x["rmse_test"] for x in gamma_data_conus_1mon])
# rmse_train = np.abs([x["rmse_train"] for x in gamma_data])
labels_permian = [x["label"] for x in gamma_data_permian]
labels_us = [x["label"] for x in gamma_data_us]
labels_global = [x["label"] for x in gamma_data_global]
labels_conus1mon = [x["label"] for x in gamma_data_conus_1mon]

ja_permian = [x["Ja"] for x in gamma_data_permian]
ja_us = [x["Ja"] for x in gamma_data_us]
ja_global = [x["Ja"] for x in gamma_data_global]
ja_conus1mon = [x["Ja"] for x in gamma_data_conus_1mon]

# make fig with 2 axs
fig, axs = plt.subplots(2, 2, figsize=(20, 15))
axs = axs.ravel()
axs[0].plot(labels_permian, np.array(rmse_test_permian)*0, color="blue", linestyle="--", label="Zero Bias Line")
axs[0].plot(labels_permian, rmse_test_permian, marker="o", label="Mean Absolute Bias Test")

axs[0].set_xlabel("Gamma")
axs[0].set_ylabel("Mean Absolute Bias Test (ppb)")
axs[0].set_title("Gamma vs Mean Absolute Bias Test: 2 weeks Permian")
# add second y axis
ax0_twin = axs[0].twinx()
ax0_twin.plot(labels_permian, ja_permian, marker="o", label="Normalized Ja value", color="red")
ax0_twin.plot(labels_permian, np.array(ja_permian)*0 +1, linestyle="--", label="Normalized Ja = 1", color="red")
ax0_twin.legend(loc="upper right")
axs[0].legend(loc="upper left")
axs[0].set_xscale("log")
ax0_twin.set_ylim(0, 5)

axs[1].plot(labels_us, np.array(rmse_test_us)*0, color="blue", linestyle="--", label="Zero Bias Line")
axs[1].plot(labels_us, rmse_test_us, marker="o", label="Mean Absolute Bias Test")

axs[1].set_xlabel("Gamma")
axs[1].set_ylabel("Mean Absolute Bias Test (ppb)")
axs[1].set_title("Gamma vs Mean Absolute Bias Test: 2019 CONUS")
# add second y axis
ax1_twin = axs[1].twinx()
ax1_twin.plot(labels_us, ja_us, marker="o", label="Normalized Ja value", color="red")
ax1_twin.plot(labels_us, np.array(ja_us)*0 +1, linestyle="--", label="Normalized Ja = 1", color="red")
ax1_twin.legend(loc="upper right")
axs[1].legend(loc="upper left")
axs[1].set_xscale("log")
ax1_twin.set_ylim(0, 5)

axs[2].plot(labels_global, np.array(rmse_test_global)*0, color="blue", linestyle="--", label="Zero Bias Line")
axs[2].plot(labels_global, rmse_test_global, marker="o", label="Mean Absolute Bias Test")

axs[2].set_xlabel("Gamma")
axs[2].set_ylabel("Mean Absolute Bias Test (ppb)")
axs[2].set_title("Gamma vs Mean Absolute Bias Test: 2019 Global")
# add second y axis
ax2_twin = axs[2].twinx()
ax2_twin.plot(labels_global, ja_global, marker="o", label="Normalized Ja value", color="red")
ax2_twin.plot(labels_global, np.array(ja_global)*0 +1, linestyle="--", label="Normalized Ja = 1", color="red")

ax2_twin.legend(loc="upper right")
axs[2].legend(loc="upper left")
axs[2].set_xscale("log")
ax2_twin.set_ylim(0, 5)

axs[3].plot(labels_conus1mon, np.array(rmse_test_conus1mon)*0, color="blue", linestyle="--", label="Zero Bias Line")
axs[3].plot(labels_conus1mon, rmse_test_conus1mon, marker="o", label="Mean Absolute Bias Test")

axs[3].set_xlabel("Gamma")
axs[3].set_ylabel("Mean Absolute Bias Test (ppb)")
axs[3].set_title("Gamma vs Mean Absolute Bias Test: US Jan 2023 Clustered")
# add second y axis
ax3_twin = axs[3].twinx()
ax3_twin.plot(labels_conus1mon, ja_global, marker="o", label="Normalized Ja value", color="red")
ax3_twin.plot(labels_conus1mon, np.array(ja_conus1mon)*0 +1, linestyle="--", label="Normalized Ja = 1", color="red")

ax3_twin.legend(loc="upper right")
axs[3].legend(loc="upper left")
axs[3].set_xscale("log")
ax3_twin.set_ylim(0, 5)
# Out:
# (0.0, 5.0)

# %%
# Adding a dashed line at y=1.0 for the Ja axis on the top left plot
# increase font size
plt.rcParams.update({'font.size': 15})
# Create figure and axes
fig, axs = plt.subplots(2, 2, figsize=(20, 10))
axs = axs.ravel()

# Top left plot with twin y-axis for ja values
ax1 = axs[0]
ax1.plot(labels, rmse_test, marker="o", label="Mean Absolute Bias Test")
ax1.set_xlabel("Gamma")
ax1.set_ylabel("Mean Absolute Bias Test (ppb)")
ax1.set_title("Gamma vs Mean Absolute Bias Test")
ax1.set_xscale("log")

# Twin y-axis
ax2 = ax1.twinx()
ax2.plot(labels, ja, marker="o", color="red", label="Normalized Ja value")
ax2.set_ylabel("Normalized Ja", color="red")
ax2.tick_params(axis='y', labelcolor="red")

# Adding a dashed horizontal line at Ja = 1.0
ax2.axhline(y=1.0, color="red", linestyle="--", linewidth=1)

# Legend
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

# Top right plot
subset = 5
axs[1].plot(labels[:subset], rmse_test[:subset], marker="o", label="Mean Absolute Bias Test")
axs[1].set_xlabel("Gamma")
axs[1].set_ylabel("Mean Absolute Bias Test (ppb)")
axs[1].set_title("Gamma vs Mean Absolute Bias Test Zoomed into elbow")
for i, txt in enumerate(labels[:subset]):
    axs[1].annotate(txt, (labels[i], rmse_test[i]))
axs[1].set_xscale("log")

# Bottom left plot
subset = 5
axs[2].plot(labels, rmse_train, marker="o", label="Mean Absolute Bias Train")
axs[2].set_xlabel("Gamma")
axs[2].set_ylabel("Mean Absolute Bias Train (ppb)")
axs[2].set_title("Gamma vs Mean Absolute Bias Train")
axs[2].set_xscale("log")

# Bottom right plot
# axs[3].plot(labels, np.abs(np.array(rmse_test) - np.array(rmse_train)), marker="o", label="Mean Absolute Bias Train")
# axs[3].set_xlabel("Gamma")
# axs[3].set_ylabel("Difference")
# axs[3].set_title("Absolute difference between Mean Absolute Bias Test and Mean Absolute Bias Train")
ax3_1 = axs[3]
ax3_1.plot(labels, np.abs(np.array(rmse_test) - np.array(rmse_train)), marker="o", label="Absolute difference")
ax3_1.set_xlabel("Gamma")
ax3_1.set_ylabel("Difference (ppb)")
ax3_1.set_title("Absolute difference between Bias Test and Bias Train")
ax3_1.set_xscale("log")


# Twin y-axis
ax3_2 = ax3_1.twinx()
ax3_2.plot(labels, ja, marker="o", color="red", label="Normalized Ja value")
ax3_2.set_ylabel("Normalized Ja", color="red")
ax3_2.tick_params(axis='y', labelcolor="red")

# Adding a dashed horizontal line at Ja = 1.0
ax3_2.axhline(y=1.0, color="red", linestyle="--", linewidth=1)

# Legend
ax3_1.legend(loc="upper left")
ax3_2.legend(loc="upper right")


# Display the plot
plt.tight_layout()
plt.show()
